# %%
import pandas as pd
import glob

file_list=[]
for num in range(16):
    file_list.append('./Naver_key_word_data'+str(num+1)+'.xlsx')

merged_data = pd.DataFrame()

for file_path in file_list:
    data = pd.read_excel(file_path)
    merged_data = merged_data.append(data)

merged_data.to_excel('merged_file.xlsx', index=False)
# Out:
# C:\Users\poror\AppData\Local\Temp\ipykernel_22248\1571535526.py:12: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   merged_data = merged_data.append(data)
# C:\Users\poror\AppData\Local\Temp\ipykernel_22248\1571535526.py:12: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   merged_data = merged_data.append(data)
# C:\Users\poror\AppData\Local\Temp\ipykernel_22248\1571535526.py:12: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   merged_data = merged_data.append(data)
# C:\Users\poror\AppData\Local\Temp\ipykernel_22248\1571535526.py:12: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   merged_data = merged_data.append(data)
# ...

# %%
firsh_num=0
second_num=0
third_num=0
fourth_num=0

for second in merged_data["second_answer"]:
    if second != "[None]":
        second_num+=1

# %%
print(second_num)
# Out:
# 174707

# %%
third_num=0
for third in merged_data["third_answer"]:
    if third != "[None]":
        third_num+=1
print(third_num)
# Out:
# 110225

# %%
third_num=0
for third in merged_data["fourth_answer"]:
    if third != "[None]":
        third_num+=1
print(third_num)
# Out:
# 73239

# %%
third_num=0
for third in merged_data["first_answer"]:
    if third != "[None]":
        third_num+=1
    else:
        print(merged_data['url'])
print(third_num)
# Out:
# 0        ['https://kin.naver.com/qna/detail.naver?d1id=...
# 1        ['https://kin.naver.com/qna/detail.naver?d1id=...
# 2        ['https://kin.naver.com/qna/detail.naver?d1id=...
# 3        ['https://kin.naver.com/qna/detail.naver?d1id=...
# 4        ['https://kin.naver.com/qna/detail.naver?d1id=...
#                                ...
# 38018    ['https://kin.naver.com/qna/detail.naver?d1id=...
# 38019    ['https://kin.naver.com/qna/detail.naver?d1id=...
# 38020    ['https://kin.naver.com/qna/detail.naver?d1id=...
# 38021    ['https://kin.naver.com/qna/detail.naver?d1id=...
# 38022    ['https://kin.naver.com/qna/detail.naver?d1id=...
# Name: url, Length: 323168, dtype: object
# 0        ['https://kin.naver.com/qna/detail.naver?d1id=...
# 1        ['https://kin.naver.com/qna/detail.naver?d1id=...
# 2        ['https://kin.naver.com/qna/detail.naver?d1id=...
# 3        ['https://kin.naver.com/qna/detail.naver?d1id=...
# 4        ['https://kin.naver.com/qna/detail.naver?d1id=...
# ...

# %%
print(len(merged_data))
# Out:
# 323168
